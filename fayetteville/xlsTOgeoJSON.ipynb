# %%
import pandas as pd
import stateplane as sp
import numpy as np
import os, requests, zipfile, StringIO
import re
import json as json

# %%
# get url
#r = requests.get('https://s3-us-west-2.amazonaws.com/openpolicingdata/Fayetteville-11-09-15.xls.zip')
#z = zipfile.ZipFile(StringIO.StringIO(r.content))

# %%
# create dirs and extract fayetteville file
#tmpdir = os.path.join(os.getcwd(), 'temp')
#os.mkdir(tmpdir)
#f = z.namelist()[0]
#z.extract(f, tmpdir)

# %%
filename = 'Fayetteville geolocational data.xls'
df0 = pd.read_excel(os.path.join(os.getcwd(), filename), sheetname=0)
df1 = pd.read_excel(os.path.join(os.getcwd(), filename), sheetname=1)

# %%
frames = [df0, df1]

df = pd.concat(frames)

# %%
df = df.set_index('TSR ID')
df.head()
# Out:
#                 City  Consent Consent By  Contraband-Alcohol  \
# TSR ID
# 154046  FAYETTEVILLE        0       COND                   0
# 183274  FAYETTEVILLE        0       COND                   0
# 154661  FAYETTEVILLE        0       COND                   0
# 154054  FAYETTEVILLE        0       COND                   0
# 154265  FAYETTEVILLE        0       COND                   0
#
#         Contraband-Drugs  Contraband-Money  Contraband-Other  \
# TSR ID
# 154046                 0                 0                 0
# 183274                 0                 0                 0
# 154661                 0                 0                 0
# 154054                 0                 0                 0
# 154265                 0                 0                 0
#
#         Contraband-Weapons  Erratic/Suspicious Behavior  Incident to Arrest  \
# TSR ID
# 154046                   0                            0                   0
# 183274                   0                            0                   0
# 154661                   0                            0                   0
# 154054                   0                            0                   0
# 154265                   0                            0                   0
#
#         Informant Tip  Injuries occurred to Passenger  \
# TSR ID
# 154046              0                               0
# 183274              0                               0
# 154661              0                               0
# 154054              0                               0
# 154265              0                               0
#
#         Injuries occurred to the driver  Injuries occurred to the officer  \
# TSR ID
# 154046                                0                                 0
# 183274                                0                                 0
# 154661                                0                                 0
# 154054                                0                                 0
# 154265                                0                                 0
#
#         Observation of Suspected Contraband  \
# TSR ID
# 154046                                    0
# 183274                                    0
# 154661                                    0
# 154054                                    0
# 154265                                    0
#
#         Officer engaged in the use of force  \
# TSR ID
# 154046                                    0
# 183274                                    0
# 154661                                    0
# 154054                                    0
# 154265                                    0
#
#         Officer: Encountered Physcial Resistance  Other Offical Information  \
# TSR ID
# 154046                                         0                          0
# 183274                                         0                          0
# 154661                                         0                          0
# 154054                                         0                          0
# 154265                                         0                          0
#
#         Probable Cause Reason Consent Requested
# TSR ID
# 154046               0                     TRAF ...
# 183274               0                     TRAF ...
# 154661               0                     TRAF ...
# 154054               0                     TRAF ...
# 154265               0                     TRAF ...
#
# [5 rows x 38 columns]

# %%
#os.remove(os.path.join(tmpdir, f))
#os.rmdir(tmpdir)

# # set path and import
# f = os.path.expanduser("~/Downloads/Fayetteville geolocational data.xls")
# dfs = pd.read_excel(f, sheetname=[0,1]) # dictionary of data frames
# df = pd.concat(dfs, ignore_index=True) # stack

# convert stateplane coords to lat long
df[['geox', 'geoy']] = df[['geox', 'geoy']].apply(lambda x: sp.to_latlon(x['geox']/100*0.3048,
  x['geoy']/100*0.3048, epsg='2264'), axis=1) # convert
df.head()
# Out:
#                 City  Consent Consent By  Contraband-Alcohol  \
# TSR ID
# 154046  FAYETTEVILLE        0       COND                   0
# 183274  FAYETTEVILLE        0       COND                   0
# 154661  FAYETTEVILLE        0       COND                   0
# 154054  FAYETTEVILLE        0       COND                   0
# 154265  FAYETTEVILLE        0       COND                   0
#
#         Contraband-Drugs  Contraband-Money  Contraband-Other  \
# TSR ID
# 154046                 0                 0                 0
# 183274                 0                 0                 0
# 154661                 0                 0                 0
# 154054                 0                 0                 0
# 154265                 0                 0                 0
#
#         Contraband-Weapons  Erratic/Suspicious Behavior  Incident to Arrest  \
# TSR ID
# 154046                   0                            0                   0
# 183274                   0                            0                   0
# 154661                   0                            0                   0
# 154054                   0                            0                   0
# 154265                   0                            0                   0
#
#         Informant Tip  Injuries occurred to Passenger  \
# TSR ID
# 154046              0                               0
# 183274              0                               0
# 154661              0                               0
# 154054              0                               0
# 154265              0                               0
#
#         Injuries occurred to the driver  Injuries occurred to the officer  \
# TSR ID
# 154046                                0                                 0
# 183274                                0                                 0
# 154661                                0                                 0
# 154054                                0                                 0
# 154265                                0                                 0
#
#         Observation of Suspected Contraband  \
# TSR ID
# 154046                                    0
# 183274                                    0
# 154661                                    0
# 154054                                    0
# 154265                                    0
#
#         Officer engaged in the use of force  \
# TSR ID
# 154046                                    0
# 183274                                    0
# 154661                                    0
# 154054                                    0
# 154265                                    0
#
#         Officer: Encountered Physcial Resistance  Other Offical Information  \
# TSR ID
# 154046                                         0                          0
# 183274                                         0                          0
# 154661                                         0                          0
# 154054                                         0                          0
# 154265                                         0                          0
#
#         Probable Cause Reason Consent Requested
# TSR ID
# 154046               0                     TRAF ...
# 183274               0                     TRAF ...
# 154661               0                     TRAF ...
# 154054               0                     TRAF ...
# 154265               0                     TRAF ...
#
# [5 rows x 38 columns]

# %%
#lat = pd.Series([v[0] for v in latlon])
#lon = pd.Series([v[1] for v in latlon])
#latlon = pd.concat([lat, lon], axis = 1)
#latlon.columns = [u'lat', u'lon']

# %%
#frames = [df, latlon]

# %%
#df = pd.DataFrame.combine(df, latlon, overwrite=True)
df[['geox', 'geoy']].head()
# Out:
#              geox       geoy
# TSR ID
# 154046  35.055092 -78.972573
# 183274  35.131864 -78.900536
# 154661  35.059468 -78.952892
# 154054  35.049573 -78.869472
# 154265  35.072020 -78.952193
#
# [5 rows x 2 columns]

# %%
# change column names and remove odd values
df.columns = [x.lower() for x in df.columns]
rx = re.compile('\W+') # get all nonnumeric values (including spaces)
df.columns = [rx.sub('_', v) for v in df.columns] # all spaces to underscores

# FIX errors in 'state'
df.state = 'NC'

# change all nonnumeric values to strings
## code from http://stackoverflow.com/questions/20670370/pandas-and-unicode
types = df.apply(lambda x: pd.lib.infer_dtype(x.values))

for col in types[(types=='unicode') | (types=='mixed')].index:
  df[col] = df[col].astype(str)

# %%
#following function thanks to Geoff Boeing @ http://geoffboeing.com/2015/10/exporting-python-data-geojson/

def df_to_geojson(df, properties, lat='geox', lon='geoy'):
    geojson = {'type':'FeatureCollection', 'features':[]}
    for _, row in df.iterrows():
        feature = {'type':'Feature',
                   'properties':{},
                   'geometry':{'type':'Point',
                               'coordinates':[]}}
        feature['geometry']['coordinates'] = [row[lon],row[lat]]
        for prop in properties:
            feature['properties'][prop] = row[prop]
        geojson['features'].append(feature)
    return geojson

cols = ['sex', 'race', 'ethnic', 'age', 'street']
geojson = df_to_geojson(df, cols)

# %%
output_filename = 'FayGeoData.js'
with open(output_filename, 'wb') as output_file:
    output_file.write('var dataset = ')
    json.dump(geojson, output_file, indent=2)
